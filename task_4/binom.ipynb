# %%
import numpy as np
import scipy.stats as sps

import matplotlib.pyplot as plt
import matplotlib.cm as cm
from mpl_toolkits.mplot3d import Axes3D
import ipywidgets as widgets

import typing

# %matplotlib inline

# %%
size = 400
grid = np.linspace(-1.0, 5.0, size)
n = 10
p = 0.45
sample = sps.binom.rvs(n=n, p=p, loc=0, size=size)

plt.scatter(
    sample,
    np.zeros(size),
    alpha = 0.4,
    label = "Случайная величина"
)

plt.hist(
    sample,
    bins = 10,
    density = True,
    alpha = 0.4,
    color = "orange"
)

plt.plot(
    grid,
    sps.binom.cdf(grid, n=n, loc=0, p=p),
    color = 'red',
    linewidth = 3,
    label = "Плотность случайной величины\nn={} p={:.2f}".format(n, p)
)

plt.legend()
plt.grid(ls=':')
plt.show()

# %%
n_arr = np.arange(1, 100, 10)

for n in n_arr:
    size = 400
    grid = np.linspace(-1.0, 10.0, size)
    p = 0.45
    sample = sps.binom.rvs(n=n, p=p, loc=0, size=size)

    plt.plot(
        grid,
        sps.binom.cdf(grid, n=n, loc=0, p=p),
        color = 'red',
        linewidth = 3,
        label = "Плотность случайной величины\nn={} p={:.2f}".format(n, p)
    )

    plt.legend()
    plt.grid(ls=':')
    plt.show()

# %%
p_arr = np.arange(0, 1, 0.1)

for p in p_arr:
    size = 400
    grid = np.linspace(-1.0, 5.0, size)
    n = 5
    sample = sps.binom.rvs(n=n, p=p, loc=0, size=size)

    plt.plot(
        grid,
        sps.binom.ppf(grid, n=n, loc=0, p=p),
        color = 'red',
        linewidth = 3,
        label = "Плотность случайной величины\nn={} p={:.2f}".format(n, p)
    )

    plt.legend()
    plt.grid(ls=':')
    plt.show()

# %% [markdown]
# В зависимости от параметра n увеличивется или уменьшается количестов лесенок в графике функции распределения причем видно, что она все больше становиться похожим на пуассоновское распределение, а параметр p влияет на смещение основной массы, причем у P=1/2 видно что количестов перходов равно равно n.
